# %% [markdown]
# # Search Metrics
#
# # DCG
#
# <div>
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/d7ce96a2916c5eb451c4da5a1bce54fc9a2f7894" width="200"/>
# </div>
#
# https://en.wikipedia.org/wiki/Discounted_cumulative_gain
#
# "Discounted cumulative gain (DCG) is a measure of ranking quality. In information retrieval, it is often used to measure effectiveness of web search engine algorithms or related applications. Using a graded relevance scale of documents in a search-engine result set, DCG measures the usefulness, or gain, of a document based on its position in the result list. The gain is accumulated from the top of the result list to the bottom, with the gain of each result discounted at lower ranks."
#
# - Sum of ((2^relevance score -1)/ log2 (position of document +1) )  for the top N documents
#
# ## How do we go from human ratings to a dcg score for each query?
#
# - Import an example and notice the first one has disagreement, see [Raw-Data](#Raw-Data)

# %%
from example import *
raw_df = pd.read_csv('assets/example-dcg.csv')
raw_df[:8]
# Out:
#    queryid         query document  position  rating_1  rating_2  rating_3
# 0        1  disagreement     doc1         1         2         2         3
# 1        1  disagreement     doc2         2         3         3         2
# 2        1  disagreement     doc3         3         0         0         2
# 3        1  disagreement     doc4         4         1         1         0
# 4        2      adhesive     doc5         1         0         0         0
# 5        2      adhesive     doc6         2         0         0         0
# 6        2      adhesive     doc7         3         0         0         0
# 7        2      adhesive     doc8         4         0         0         0

# %% [markdown]
# ## Normalize relevance by taking the median rating

# %%
verbose_df = raw_df.copy()
verbose_df['relevance'] = raw_df[['rating_1', 'rating_2', 'rating_3']].median(axis=1).astype(int)
verbose_df[:4]
# Out:
#    queryid         query document  position  rating_1  rating_2  rating_3  \
# 0        1  disagreement     doc1         1         2         2         3
# 1        1  disagreement     doc2         2         3         3         2
# 2        1  disagreement     doc3         3         0         0         2
# 3        1  disagreement     doc4         4         1         1         0
#
#    relevance
# 0          2
# 1          3
# 2          0
# 3          1

# %%
df = verbose_df[['query', 'document', 'position', 'relevance']].copy() # strip away the ratings

# %% [markdown]
# ## How is DCG calculated?
#
# Sum of ((2^relevance score -1)/ log2 (position of document +1) )  for the top N documents.
#
# <div>
# <img src="https://i.imgur.com/unhes8l.png" width="200"/>
# </div>
#
# Calculate the gain by raising the relevance score to the second power (punish those bad hits!).
#
# Don't forget the -1 😀

# %%
df['gain'] = np.power(2, df['relevance']) - 1
df[:4]
# Out:
#           query document  position  relevance  gain
# 0  disagreement     doc1         1          2     3
# 1  disagreement     doc2         2          3     7
# 2  disagreement     doc3         3          0     0
# 3  disagreement     doc4         4          1     1

# %% [markdown]
# <div>
# <img src="https://i.imgur.com/0kpe3Eq.png" width="200"/>
# </div>
#
# Calculate the position discount.

# %%
df['discount'] = np.log2(df['position']  + 1)
df[:4]
# Out:
#           query document  position  relevance  gain  discount
# 0  disagreement     doc1         1          2     3  1.000000
# 1  disagreement     doc2         2          3     7  1.584963
# 2  disagreement     doc3         3          0     0  2.000000
# 3  disagreement     doc4         4          1     1  2.321928

# %% [markdown]
# Calculate the discounted gain:
# - (2^relevance score -1) / log2 (position of document +1)
#
# ie gain / discount.

# %%
df['dg'] = np.nan_to_num(df['gain'] / df['discount']) # Replace NaN with zero
df[:4]
# Out:
#           query document  position  relevance  gain  discount        dg
# 0  disagreement     doc1         1          2     3  1.000000  3.000000
# 1  disagreement     doc2         2          3     7  1.584963  4.416508
# 2  disagreement     doc3         3          0     0  2.000000  0.000000
# 3  disagreement     doc4         4          1     1  2.321928  0.430677

# %% [markdown]
# Sum this up cumulatively and we have dcg:

# %%
df['dcg'] = df.groupby(['query'])['dg'].cumsum()
df[:4]
# Out:
#           query document  position  relevance  gain  discount        dg  \
# 0  disagreement     doc1         1          2     3  1.000000  3.000000
# 1  disagreement     doc2         2          3     7  1.584963  4.416508
# 2  disagreement     doc3         3          0     0  2.000000  0.000000
# 3  disagreement     doc4         4          1     1  2.321928  0.430677
#
#         dcg
# 0  3.000000
# 1  7.416508
# 2  7.416508
# 3  7.847185

# %% [markdown]
# Add in the cumulative gain and ideal rank order.

# %%
df['ideal_rank'] = df.groupby(['query'])['relevance'].rank(method='dense', ascending=False).astype(int)
df['cg'] = df.groupby(['query'])['relevance'].cumsum()
df[:4]
# Out:
#           query document  position  relevance  gain  discount        dg  \
# 0  disagreement     doc1         1          2     3  1.000000  3.000000
# 1  disagreement     doc2         2          3     7  1.584963  4.416508
# 2  disagreement     doc3         3          0     0  2.000000  0.000000
# 3  disagreement     doc4         4          1     1  2.321928  0.430677
#
#         dcg  ideal_rank  cg
# 0  3.000000           2   2
# 1  7.416508           1   5
# 2  7.416508           4   5
# 3  7.847185           3   6

# %% [markdown]
# ## What impact does relevance have on dcg?
#
# - the lowest score

# %%
df[4:8]
# Out:
#       query document  position  relevance  gain  discount   dg  dcg  \
# 4  adhesive     doc5         1          0     0  1.000000  0.0  0.0
# 5  adhesive     doc6         2          0     0  1.584963  0.0  0.0
# 6  adhesive     doc7         3          0     0  2.000000  0.0  0.0
# 7  adhesive     doc8         4          0     0  2.321928  0.0  0.0
#
#    ideal_rank  cg
# 4           1   0
# 5           1   0
# 6           1   0
# 7           1   0

# %% [markdown]
# - Add in a relevant document

# %%
df[8:12]
# Out:
#     query document  position  relevance  gain  discount        dg       dcg  \
# 8   boots     doc9         1          0     0  1.000000  0.000000  0.000000
# 9   boots    doc10         2          0     0  1.584963  0.000000  0.000000
# 10  boots    doc11         3          0     0  2.000000  0.000000  0.000000
# 11  boots    doc12         4          1     1  2.321928  0.430677  0.430677
#
#     ideal_rank  cg
# 8            2   0
# 9            2   0
# 10           2   0
# 11           1   1

# %% [markdown]
# - Gradually getting better until 'frying pan' gets a perfect score of 17.93 at rank 4

# %%
df[4:28]
# Out:
#              query document  position  relevance  gain  discount        dg  \
# 4         adhesive     doc5         1          0     0  1.000000  0.000000
# 5         adhesive     doc6         2          0     0  1.584963  0.000000
# 6         adhesive     doc7         3          0     0  2.000000  0.000000
# 7         adhesive     doc8         4          0     0  2.321928  0.000000
# 8            boots     doc9         1          0     0  1.000000  0.000000
# 9            boots    doc10         2          0     0  1.584963  0.000000
# 10           boots    doc11         3          0     0  2.000000  0.000000
# 11           boots    doc12         4          1     1  2.321928  0.430677
# 12          camera    doc13         1          0     0  1.000000  0.000000
# 13          camera    doc14         2          0     0  1.584963  0.000000
# 14          camera    doc15         3          0     0  2.000000  0.000000
# 15          camera    doc16         4          3     7  2.321928  3.014736
# 16            door    doc17         1          3     7  1.000000  7.000000
# 17            door    doc18         2          0     0  1.584963  0.000000
# 18            door    doc19         3          0     0  2.000000  0.000000
# 19            door    doc20         4          0     0  2.321928  0.000000
# 20  extension cord    doc21         1          3     7  1.000000  7.000000
# 21  extension cord    doc22         2          1     1  1.584963  0.630930
# 22  extension cord    doc23         3          1     1  2.000000  0.500000
# 23  extension cord    doc24         4          1     1  2.321928  0.430677
# 24      frying pan    doc25         1          3     7  1.000000  7.000000
# 25      frying pan    doc26         2          3     7  1.584963  4.416508
# 26      frying pan    doc27         3          3     7  2.000000  3.500000
# 27      frying pan    doc28         4          3     7  2.321928  3.014736
#
#           dcg  ideal_rank  cg
# 4    0.000000           1   0
# 5    0.000000           1   0
# 6    0.000000           1   0
# 7    0.000000           1   0
# 8    0.000000           2   0
# 9    0.000000           2   0
# 10   0.000000           2   0
# 11   0.430677           1   1
# 12   0.000000           2   0
# 13   0.000000           2   0
# 14   0.000000           2   0
# 15   3.014736           1   3
# 16   7.000000           1   3
# 17   7.000000           2   3
# 18   7.000000           2   3
# 19   7.000000           2   3
# 20   7.000000           1   3
# 21   7.630930           2   4
# 22   8.130930           2   5
# 23   8.561606           2   6
# 24   7.000000           1   3
# 25  11.416508           1   6
# 26  14.916508           1   9
# 27  17.931244           1  12

# %% [markdown]
# ## Rank the queries by dcg to see low performing opportunities
#
# - the next step would be to look in the logs for how many "adhesive" like queries there are
# - what is it about "frying pan" that is enabling us to handle them so well

# %%
df[['query', 'dcg']].groupby("query", as_index=False).last()\
.sort_values(by='dcg', ascending=True).reset_index(drop=True)
# Out:
#              query        dcg
# 0         adhesive   0.000000
# 1            boots   0.430677
# 2           nDCG A   2.892789
# 3           camera   3.014736
# 4             door   7.000000
# 5          control   7.847185
# 6     disagreement   7.847185
# 7   extension cord   8.561606
# 8             test   9.392789
# 9           nDCG B  12.392789
# 10      frying pan  17.931244

# %% [markdown]
# ## Compare two algorithms offline
#
# - We can then evaluate the performance of an algorithm and compare two versions offline
# - Notice that test has reordered documents 30-33 and put the most relevant document at the top

# %%
df[28:36]
# Out:
#       query document  position  relevance  gain  discount        dg       dcg  \
# 28  control    doc30         1          2     3  1.000000  3.000000  3.000000
# 29  control    doc31         2          3     7  1.584963  4.416508  7.416508
# 30  control    doc32         3          0     0  2.000000  0.000000  7.416508
# 31  control    doc33         4          1     1  2.321928  0.430677  7.847185
# 32     test    doc31         1          3     7  1.000000  7.000000  7.000000
# 33     test    doc30         2          2     3  1.584963  1.892789  8.892789
# 34     test    doc33         3          1     1  2.000000  0.500000  9.392789
# 35     test    doc32         4          0     0  2.321928  0.000000  9.392789
#
#     ideal_rank  cg
# 28           2   2
# 29           1   5
# 30           4   5
# 31           3   6
# 32           1   3
# 33           2   5
# 34           3   6
# 35           4   6

# %% [markdown]
# # nDCG
#
# ![](https://wikimedia.org/api/rest_v1/media/math/render/svg/b3510c9c5cf42ee8820d65335675cada51b40736)
#
# nDCG is actual DCG/ideal DCG

# %%
#TODO add examples showing why nDCG is only good as a comparison metric

# %% [markdown]
# ## Raw Data

# %%
raw_df.to_json()
# Out:
# '{"queryid":{"0":1,"1":1,"2":1,"3":1,"4":2,"5":2,"6":2,"7":2,"8":3,"9":3,"10":3,"11":3,"12":4,"13":4,"14":4,"15":4,"16":5,"17":5,"18":5,"19":5,"20":6,"21":6,"22":6,"23":6,"24":7,"25":7,"26":7,"27":7,"28":8,"29":8,"30":8,"31":8,"32":9,"33":9,"34":9,"35":9,"36":10,"37":10,"38":10,"39":10,"40":11,"41":11,"42":11,"43":11},"query":{"0":"disagreement","1":"disagreement","2":"disagreement","3":"disagreement","4":"adhesive","5":"adhesive","6":"adhesive","7":"adhesive","8":"boots","9":"boots","10":"boots","11":"boots","12":"camera","13":"camera","14":"camera","15":"camera","16":"door","17":"door","18":"door","19":"door","20":"extension cord","21":"extension cord","22":"extension cord","23":"extension cord","24":"frying pan","25":"frying pan","26":"frying pan","27":"frying pan","28":"control","29":"control","30":"control","31":"control","32":"test","33":"test","34":"test","35":"test","36":"nDCG A","37":"nDCG A","38":"nDCG A","39":"nDCG A","40":"nDCG B","41":"nDCG B","42":"nDCG B","43":"nDCG B"},"document":{"0":"doc1","1":"doc2","2":"doc3","3":"doc4","4":"doc5","5":"doc6","6":"doc7","7":"doc8","8":"doc9","9":"doc10","10":"doc11","11":"doc12","12":"doc13","13":"doc14","14":"doc15","15":"doc16","16":"doc17","17":"doc18","18":"doc19","19":"doc20","20":"doc21","21":"doc22","22":"doc23","23":"doc24","24":"doc25","25":"doc26","26":"doc27","27":"doc28","28":"doc30","29":"doc31","30":"doc32","31":"doc33","32":"doc31","33":"doc30","34":"doc33","35":"doc32","36":"doc34","37":"doc35","38":"doc36","39":"doc37","40":"doc38","41":"doc39","42":"doc40","43":"doc41"},"position":{"0":1,"1":2,"2":3,"3":4,"4":1,"5":2,"6":3,"7":4,"8":1,"9":2,"10":3,"11":4,"12":1,"13":2,"14":3,"15":4,"16":1,"17":2,"18":3,"19":4,"20":1,"21":2,"22":3,"23":4,"24":1,"25":2,"26":3,"27":4,"28":1,"29":2,"30":3,"31":4,"32":1,"33":2,"34":3,"35":4,"36":2,"37":1,"38":0,"39":0,"40":2,"41":3,"42":3,"43":3},"rating_1":{"0":2,"1":3,"2":0,"3":1,"4":0,"5":0,"6":0,"7":0,"8":0,"9":0,"10":0,"11":1,"12":0,"13":0,"14":0,"15":3,"16":3,"17":0,"18":0,"19":0,"20":3,"21":1,"22":1,"23":1,"24":3,"25":3,"26":3,"27":3,"28":2,"29":3,"30":0,"31":1,"32":3,"33":2,"34":1,"35":0,"36":2,"37":1,"38":0,"39":0,"40":2,"41":3,"42":3,"43":3},"rating_2":{"0":2,"1":3,"2":0,"3":1,"4":0,"5":0,"6":0,"7":0,"8":0,"9":0,"10":0,"11":1,"12":0,"13":0,"14":0,"15":3,"16":3,"17":0,"18":0,"19":0,"20":3,"21":1,"22":1,"23":1,"24":3,"25":3,"26":3,"27":3,"28":2,"29":3,"30":0,"31":1,"32":3,"33":2,"34":1,"35":0,"36":2,"37":1,"38":0,"39":0,"40":2,"41":3,"42":3,"43":3},"rating_3":{"0":3,"1":2,"2":2,"3":0,"4":0,"5":0,"6":0,"7":0,"8":0,"9":0,"10":0,"11":1,"12":0,"13":0,"14":0,"15":3,"16":3,"17":0,"18":0,"19":0,"20":3,"21":1,"22":1,"23":1,"24":3,"25":3,"26":3,"27":3,"28":2,"29":3,"30":0,"31":1,"32":3,"33":2,"34":1,"35":0,"36":2,"37":1,"38":0,"39":0,"40":2,"41":3,"42":3,"43":3}}'

# %%
raw_df
# Out:
#     queryid           query document  position  rating_1  rating_2  rating_3
# 0         1    disagreement     doc1         1         2         2         3
# 1         1    disagreement     doc2         2         3         3         2
# 2         1    disagreement     doc3         3         0         0         2
# 3         1    disagreement     doc4         4         1         1         0
# 4         2        adhesive     doc5         1         0         0         0
# 5         2        adhesive     doc6         2         0         0         0
# 6         2        adhesive     doc7         3         0         0         0
# 7         2        adhesive     doc8         4         0         0         0
# 8         3           boots     doc9         1         0         0         0
# 9         3           boots    doc10         2         0         0         0
# 10        3           boots    doc11         3         0         0         0
# 11        3           boots    doc12         4         1         1         1
# 12        4          camera    doc13         1         0         0         0
# 13        4          camera    doc14         2         0         0         0
# 14        4          camera    doc15         3         0         0         0
# 15        4          camera    doc16         4         3         3         3
# 16        5            door    doc17         1         3         3         3
# 17        5            door    doc18         2         0         0         0
# 18        5            door    doc19         3         0         0         0
# 19        5            door    doc20         4         0         0         0
# 20        6  extension cord    doc21         1         3         3         3
# 21        6  extension cord    doc22         2         1         1         1
# 22        6  extension cord    doc23         3         1         1         1
# 23        6  extension cord    doc24         4         1         1         1
# 24        7      frying pan    doc25         1         3         3         3
# 25        7      frying pan    doc26         2         3         3         3
# 26        7      frying pan    doc27         3         3         3         3
# 27        7      frying pan    doc28         4         3         3         3
# 28        8         control    doc30         1         2         2         2
# 29        8         control    doc31         2         3         3         3
# 30        8         control    doc32         3         0         0         0
# 31        8         control    doc33         4         1         1         1
# 32        9            test    doc31         1         3         3         3
# 33        9            test    doc30         2         2         2         2
# 34        9            test    doc33         3         1         1         1
# 35        9            test    doc32         4         0         0         0
# 36       10          nDCG A    doc34         2         2         2         2
# 37       10          nDCG A    doc35         1         1         1         1
# 38       10          nDCG A    doc36         0         0         0         0
# 39       10          nDCG A    doc37         0         0         0         0
# 40       11          nDCG B    doc38         2         2         2         2
# 41       11          nDCG B    doc39         3         3         3         3
# 42       11          nDCG B    doc40         3         3         3         3
# 43       11          nDCG B    doc41         3         3         3         3
